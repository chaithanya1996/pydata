# %%
import pandas_datareader as pdd

# %%
import datetime
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2013, 1, 27)
google_data = pdd.DataReader("F", 'google', start, end)

# %%
f.head()
# Out:
#              Open   High    Low  Close     Volume
# Date
# 2010-01-04  10.17  10.28  10.05  10.28   60855796
# 2010-01-05  10.45  11.24  10.40  10.96  215620138
# 2010-01-06  11.21  11.46  11.13  11.37  200070554
# 2010-01-07  11.46  11.69  11.32  11.66  130201626
# 2010-01-08  11.67  11.74  11.46  11.69  130462912

# %%
yahoo_data = pdd.DataReader("F", 'yahoo', start, end)
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-12-a2234a96d6da> in <module>()
# ----> 1 yahoo_data = pdd.DataReader("F", 'yahoo', start, end)
#
# /home/chaithanya/anaconda3/lib/python3.6/site-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, access_key)
#     115                                 adjust_price=False, chunksize=25,
#     116                                 retry_count=retry_count, pause=pause,
# --> 117                                 session=session).read()
#     118
#     119     elif data_source == "yahoo-actions":
#
# /home/chaithanya/anaconda3/lib/python3.6/site-packages/pandas_datareader/yahoo/daily.py in read(self)
#      75     def read(self):
#      76         """ read one data from specified URL """
# ---> 77         df = super(YahooDailyReader, self).read()
# ...

# %%
amzn = pdd.get_quote_yahoo('AMZN')

# %%
pdd.
# Out:
#           PE change_pct    last  short_ratio    time
# AMZN  186.01     +2.44%  987.71         2.09  4:00pm

# %%
component = pdd.data.get_components_yahoo("AMZN")
